# %% [markdown]
# # STA 141B Data & Web Technologies for Data Analysis
#
# ### Lecture 9, 2/8/24, Scraping

# %% [markdown]
# ### Announcements
#
#  - Homework 2 due tomorrow. Late submission will not be accepted.

# %% [markdown]
# ### Today's topics
#
#  - Scraping Tables with `pandas`
#  - HTML
#  - XML
#  - Parser
#  - Extracting Elements

# %% [markdown]
# ### Ressources
#
# * [`requests` documentation](http://docs.python-requests.org/en/master/)
# * [`requests-html` documentation](https://html.python-requests.org/)
# * [W3 Schools](https://www.w3schools.com/html/default.asp)
# * [MDN HTML Reference](https://developer.mozilla.org/en-US/docs/Web/HTML/Element)
# * [XPath Diner](http://www.topswagcode.com/xpath/) - an interactive XPath tutorial
# * [CSS Diner](https://flukeout.github.io/) - an interactive CSS Selector tutorial

# %% [markdown]
# #### Safeway
#
# Check the [docs](https://requests.readthedocs.io/en/latest/api/?requests.get)!

# %%
import requests

# %%
url = 'https://www.safeway.com/abs/pub/xapi/pgmsearch/v1/search/products'
params = {
        "request-id":9541707334938977135,
    "url":"https://www.safeway.com",
    "pageurl":"https://www.safeway.com",
    "pagename":"search",
    "rows":30,
    "start":0,
    "search-type":"keyword",
    "storeid":3132,
    "featured":"true",
    "search-uid":"",
    "q":"eggs",
    "sort":"",
    "featuredsessionid":"",
    "screenwidth":394,
    "dvid":"web-4.1search",
    "channel":"instore",
    "wineshopstoreid":5799,
    "wineshopwidgetid":"nlvkox9e",
    "timezone":"America/Los_Angeles",
    "zipcode":94611,
    "visitorId":"d42daa35-78ae-48dc-9df7-3c163dd79bc2",
    "pgm":"intg-search,wineshop",
    "banner":"safeway",
    "variant":"ACIP134410_a"
}
header = {
    'Ocp-Apim-Subscription-Key': '5e790236c84e46338f4290aa1050cdd4', 
}

# %%
results = requests.get(url, params=params)
results.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/fh/hvkm2z9n7631q5058px_kqg80000gr/T/ipykernel_11855/281845443.py in <module>
#       1 results = requests.get(url, params=params)
# ----> 2 results.raise_for_status()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 401 Client Error: Unauthorized for url: https://www.safeway.com/abs/pub/xapi/pgmsearch/v1/search/products?request-id=9541707334938977135&url=https%3A%2F%2Fwww.safeway.com&pageurl=https%3A%2F%2Fwww.safeway.com&pagename=search&rows=30&start=0&search-type=keyword&storeid=3132&featured=true&search-uid=&q=eggs&sort=&featuredsessionid=&screenwidth=394&dvid=web-4.1search&channel=instore&wineshopstoreid=5799&wineshopwidgetid=nlvkox9e&timezone=America%2FLos_Angeles&zipcode=94611&visitorId=d42daa35-78ae-48dc-9df7-3c163dd79bc2&pgm=intg-search%2Cwineshop&banner=safeway&variant=ACIP134410_a

# %%
results = requests.get(url, params=params, headers=header)
results.json()
# Out:
# {'appMsg': '[PS: Success.]',
#  'pgmList': [{'response': {'numFound': 0,
#     'start': 0,
#     'miscInfo': {'attributionToken': 'rQHwrAoMCJi8j64GEJmY8pcCEAEaJDY1ZTQ0MDU4LTAwMDAtMjVkZi04OTdiLWM4MmFkZDZjMmQxYyokZDQyZGFhMzUtNzhhZS00OGRjLTlkZjctM2MxNjNkZDc5YmMyMizHy_MX9pmEIqOAlyK4maEiwvCeFaaL7xeOvp0V1LKdFYz3pyKpwP0sifenIjobd2ViLXdpbmVzaG9wLXNlcnZpbmctY29uZmlnSAFYAWgB',
#      'query': 'eggs',
#      'filter': '(inventory(5799, price) >0) AND (inventory(5799,attributes.ship_to_store) = 1) AND (inventory(5799, attributes.shipping): ANY("1", "2") AND  ((attributes.wineEligible: ANY("WE","ALL")))  AND attributes.is_market_place_product : ANY("false"))'},
#     'shippingInfo': {'arriveByTS': '2024-02-09T20:00:00Z',
#      'displayArriveByTS': '2024-02-09T12:00:00',
#      'shippingType': 'REGULAR',
#      'minArriveByTS': '2024-02-08T20:00:00Z',
#      'displayMinArriveByTS': '2024-02-08T12:00:00'},
#     'isExactMatch': False},
#    'appCode': 'GR204 PS: 200',
#    'appMsg': 'GR : Google Retail returned empty response.. PS: Success.',
#    'pgmName': 'wineshop',
#    'order': 'g-4'}],
#  'primaryProducts': {'response': {'numFound': 1691,
#    'start': 0,
#    'miscInfo': {'attributionToken': 'qwHwqgoLCJi8j64GEMza2mkQARokNjVkMjQ5NmMtMDAwMC0yNDJmLTkxMzctYzgyYWRkNzY4Y2E4KiRkNDJkYWEzNS03OGFlLTQ4ZGMtOWRmNy0zYzE2M2RkNzliYzIyLMfL8xf2mYQio4CXIriZoSLC8J4VpovvF46-nRXUsp0VjPenIqnA_SyJ96ciOhp3ZWItc2FmZXdheS1zZXJ2aW5nLWNvbmZpZ0gBWAFoAQ',
#     'query': 'eggs',
#     'filter': '(inventory(3132, price) >0) AND (inventory(3132,attributes.custom_type_2) = 1)'},
#    'isExactMatch': True,
#    'docs': [{'status': 'active',
#      'name': 'Lucerne Farms Eggs Large Cage Free - 12 Count',
#      'pid': '960273951',
#      'upc': '0002113003234',
#      'id': '960273951',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 20,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960273951',
#      'price': 5.99,
#      'basePrice': 5.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '0.500',
#      'slotXcoordinateNbr': '35.150',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23451.780',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.7',
#       'reviewCount': '1879',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Vital Farms Organic Eggs Pasture Raised Large Grade A Tray - 12 Count',
#      'pid': '960454622',
#      'upc': '0086174500002',
#      'id': '960454622',
#      'featured': True,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 2658,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960454622',
#      'price': 10.99,
#      'basePrice': 10.99,
#      'pricePer': 0.92,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'COUNT',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      
#        'OnWishlistBeacon': '//b.da.us.criteo.com/rm?rm_e=EbaYKBzVvKtXh8A0mRhWmXYY67Ys2jr0TF6REk4ZsvJqexZ0hvndWHpEnbn3bWXytjgvwhSjZY8MlkfbK3i42yf9ieht-_95xCHGPtEX3yJus6xLAQiIlDe7PsYrpFJNaUBtd1ldducbbQand9CBoLskNdUwMJPaonP8XgyelIxg4SxCm4nebOlqmBb8K0Y14QySw0BKPSesuNrzIuIjcsstTG6mH0nqRiUMMQLVa24cFlPvE-4q1NCuIvkvhLiH748v6qQrbqU8vFTbijgLamrUl1DdWAXnlkn1FdQRp2VG__r13XlVM4_VfYuHOqt0jKZyJPKjsTteljYD8hspA6wqyM7nuPC12b-mImpi6J4RcyT7tzdXRHRskRbh74hIvSwLe03He-84fI0nIHHL7g&ev=4'}},
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '5.0',
#       'reviewCount': '4',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Lucerne Farms Eggs Cage Free Large - 18 Count',
#      'pid': '960304348',
#      'upc': '0002113003154',
#      'id': '960304348',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 36,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960304348',
#      'price': 7.99,
#      'basePrice': 7.99,
#      'pricePer': 5.33,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '0.500',
#      'slotXcoordinateNbr': '11.950',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.6',
#       'reviewCount': '1254',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Egglands Best Cage Free Large Brown Eggs  - 12 Count',
#      'pid': '138350144',
#      'upc': '0071514151464',
#      'id': '138350144',
#      'featured': True,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 325,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/138350144',
#      'price': 5.99,
#      'basePrice': 5.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '29.000',
#      'slotXcoordinateNbr': '23.300',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'triggerQuantity': 0,
#      'eventTracking': {'slotId': 0,
#       'vendorId': '2',
#       'beacons': {'OnLoadBeacon': '//b.da.us.criteo.com/rm?rm_e=f1Xn9QBNlxMlEG0bBeWS96o6NRt4zrXFPbcoFEBY4StjdQ38wvOCu6kySo3pKAI8qdpnez4xF6O3AX8Vf45bTewMN7KXlEjt6tswdTEZ2onNb7rX81vCvDWVR8O3bqwXV_PnJGPB6DQ-9SAzn5Sri3k4w-h3qApxRAxT4xeshN8pE8uDPOFM5YYtBUt55SO43d4hRLo_7SqknFm_OkGgm6ZHxHYqbmiq0tlmJ8PAmIOZEk0-sd5OmMnF1WmrSLaKRTLIhSDa5s1RKCjgAk5n6Wht4Ycp9w80T66_MLjnLEUMaxQpx5ksouvfpZM7Rv-_LIEn2iZiZxYXwAbOZgzPuA&ev=4',
#        'OnWishlistBeacon': '//b.da.us.criteo.com/rm?rm_e=-E9RDc-cohCRVnZl0Q4CzI8eJo9pg0odUJEsdgJd2dZJ34Xg-faQcID-nnyy8v0oXfuj1jdqGJNVhCLrA84tpUi4VTUg-C3xyLHgb3o0vKBPd_PhonqM7QEGLLPtwF_QSxqzofITRJZ_bdjxp4nQOpF2PzU5nCyIdbpy93G2q-soIpTIDmXMYYswsF8cjN1hfufzbnsUWv-OsDikJ13Q3qtUvh5MSMLPjULYNxCcXZOrPF9wMX6W2O87bb6z76fqbcL_HOiiKeXfQ1VN_kSb8V7sImJXwZ2Fpkyl2sciB8_GKp44V_IBNvChmIK0EKybAmCHYlg-D0qn8smXXHb27EmFsPEwfw-jbW2t6-nG4qP6HcJnAF2tkDpCrYFW4zm7KNZHitT4U9fhUCyYpl2SVw&ev=4'}},
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '1063',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Lucerne Cage Free Grade A Large Eggs - 60 Count',
#      'pid': '970116262',
#      'upc': '0002113016895',
#      'id': '970116262',
#      'featured': False,
#      'inventoryAvailable': '0',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 99999,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/970116262',
#      'price': 22.99,
#      'basePrice': 22.99,
#      'pricePer': 4.6,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '0',
#       'pickup': '0',
#       'instore': '0',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.7',
#       'reviewCount': '80',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Vital Farms Eggs Large - 12 Count',
#      'pid': '960100459',
#      'upc': '0086174500001',
#      'id': '960100459',
#      'featured': True,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 297,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960100459',
#      'price': 9.99,
#      'basePrice': 9.99,
#      'pricePer': 9.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '29.000',
#      'slotXcoordinateNbr': '58.000',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'triggerQuantity': 0,
#      'eventTracking': {'slotId': 0,
#       'vendorId': '2',
#       'beacons': {'OnLoadBeacon': '//b.da.us.criteo.com/rm?rm_e=FxDQqPTAOt7iVijaqRzJUtqN_BhhVs-vX1WeX0QcfYRpAtQRXPLPoc2gsZ2pDZeVC7AQaOqMcRAy04X4IpXQAz-F-mObcSpElQ-r6WIeBTRlL5zyOJTDbsLcuxJ5k8P2GzCj81f5q6imXmRzb0809WiPbn0Fsku1NEpANCIZqVCcpsZZ3c_ZXsL8ylUXz1toc8vEj_un5Fj47m-NYlb7owOpTaDuF7_5WY_Q8Xt673PMwioe0SKh8G5UvuaRMU1IHJ8bkNpZwM6atyxuSkUO9E_uD5UjW7Lb-fApRpFR4Kkl9iiZOdkxaHBb-J7JEWBV5uHYBs3pgq7sFhRDpJdAOQ&ev=4',
#        'OnViewBeacon': '//b.da.us.criteo.com/rm?rm_e=uXG3VfHwkSG2VIVIPDzZHjxsJ1v7TevOB9z0WVAWb2UvutDfWI6D2IEdMYLgyKDxFU2ZBFzh9SEdlqvGFgBtP3EH_nlmoYPYgbNp2peJliJ8c2kmtm6kqdMzdWSzGlrKi1ii-pNuJ5ZF7UNYhBLvdgQLVYLAVC8bY6lZ4NsX3Fl2r9
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '41',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'O Organics Organic Eggs Large Brown - 12 Count',
#      'pid': '138350308',
#      'upc': '0007989340150',
#      'id': '138350308',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 167,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/138350308',
#      'price': 5.99,
#      'basePrice': 5.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '16.000',
#      'slotXcoordinateNbr': '47.500',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '444',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Nellies Eggs Free Range Large Brown - 18 Count',
#      'pid': '960307212',
#      'upc': '0081565200421',
#      'id': '960307212',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 473,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960307212',
#      'price': 8.99,
#      'basePrice': 8.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '16.000',
#      'slotXcoordinateNbr': '71.000',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '19',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Lucerne Farms Eggs Cage Free Extra Large - 12 Count',
#      'pid': '960304347',
#      'upc': '0002113003152',
#      'id': '960304347',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 964,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960304347',
#      'price': 5.99,
#      'basePrice': 5.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '16.000',
#      'slotXcoordinateNbr': '0.000',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.7',
#       'reviewCount': '335',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Egglands Best Cage Free Large White Eggs  - 12 Count',
#      'pid': '970115360',
#      'upc': '0071514151471',
#      'id': '970115360',
#      'featured': True,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 99999,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/970115360',
#      'price': 5.49,
#      'basePrice': 5.49,
#      'pricePer': 5.49,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '29.000',
#      'slotXcoordinateNbr': '11.700',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23451.780',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      
#        'OnWishlistBeacon': '//b.da.us.criteo.com/rm?rm_e=Tsqb6S3g14uJCoj0VITugn5QzabkcQ9Y1WEQ5dSitZ1U_oMqOiEm1ekgqbNksZpA-2QL_BS4XlXOdwHKImyG4JAcC0buO3A1KLgQ5jQELuunDM_-TIY50TCja4SdAoT7U9cqsOkerUaiwn2hN6YfQDrLIXOD_uUm8EPsbY9iQkrEK4XmGFgQL90Dps1NwP3v_VbA-9Bj9tMADGoTRZF5EJXDei_gvd9_uh9xYGY8Kh7wAIiVtW0UXTsBEDOQBLaU1HWY_lZZ_fIxS6OIzSsyZHl7-0sveOyI8W-lKctU8pgC3XY1etIu9wCNdkicVU5bjHvOEwll-7QC6BIZKkh77tqa_N-OYoV1Ye6XyPrBkxNw_pNiV-KXTJxvlYHfvOhLfp3IOGUw9mBupO12y7P2pw&ev=4'}},
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '1063',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Happy Egg Co. Eggs Free Range Large - 12 Count',
#      'pid': '960100476',
#      'upc': '0088742200000',
#      'id': '960100476',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 277,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960100476',
#      'price': 5.99,
#      'promoDescription': 'Club Card Price: $5.99 Save Up To: $2.0',
#      'promoText': ' $5.99 Save Up To: $2.0',
#      'promoType': 'P',
#      'promoEndDate': '2024-02-13T23:59:00',
#      'basePrice': 7.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '16.000',
#      'slotXcoordinateNbr': '82.550',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '138',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Vital Farms Pasture-Raised Eggs - Large - 18 Count',
#      'pid': '960559633',
#      'upc': '0086231500024',
#      'id': '960559633',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 360,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960559633',
#      'price': 12.99,
#      'basePrice': 12.99,
#      'pricePer': 8.66,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '29.000',
#      'slotXcoordinateNbr': '69.730',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23451.780',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.9',
#       'reviewCount': '16',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Lucerne Farms Eggs Cage Free Jumbo - 12 Count',
#      'pid': '960309878',
#      'upc': '0002113004939',
#      'id': '960309878',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 1225,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960309878',
#      'price': 5.99,
#      'basePrice': 5.99,
#      'pricePer': 5.99,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '16.000',
#      'slotXcoordinateNbr': '11.750',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23451.780',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '327',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Signature SELECT Confetti Eggs 12 Count - Each',
#      'pid': '970457016',
#      'upc': '0002113014908',
#      'id': '970457016',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 99999,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/970457016',
#      'price': 3.0,
#      'promoDescription': 'Club Card Price: Signature Sale $3.0 Save Up To: $0.99',
#      'promoText': ' Signature Sale $3.0 Save Up To: $0.99',
#      'promoType': 'P',
#      'promoEndDate': '2024-03-31T23:59:00',
#      'basePrice': 3.99,
#      'pricePer': 3.0,
#      'displayType': '-1',
#      'aisleId': '1_14_6_6',
#      'aisleName': 'Seasonal Items|1_14_6',
#      'departmentName': 'Flowers, Cards, Occasion',
#      'shelfName': 'Easter',
#      'shelfNameWithId': 'Easter|1_14_6_6',
#      'snapEligible': False,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'EACH',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 20,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': False,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_14_6',
#      'idOfShelf': '1_14_6_6',
#      'idOfDepartment': '1_14',
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': False,
#       'delivery': False,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '0.0',
#       'reviewCount': '0',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Egglands Best Cage Free Large White Eggs  - 18 Count',
#      'pid': '970115353',
#      'upc': '0071514151474',
#      'id': '970115353',
#      'featured': False,
#      'inventoryAvailable': '0',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 99999,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/970115353',
#      'price': 7.99,
#      'basePrice': 7.99,
#      'pricePer': 0.44,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '29.000',
#      'slotXcoordinateNbr': '0.000',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23451.780',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'COUNT',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '0',
#       'pickup': '0',
#       'instore': '0',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '1063',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'O Organics Organic Eggs Large Brown - 18 Count',
#      'pid': '960096423',
#      'upc': '0007989340154',
#      'id': '960096423',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 881,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960096423',
#      'price': 7.99,
#      'basePrice': 7.99,
#      'pricePer': 5.33,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '1',
#       'pickup': '1',
#       'instore': '1',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.8',
#       'reviewCount': '230',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Open Nature Eggs Brown Free Range Large - 18 Count',
#      'pid': '960455228',
#      'upc': '0007989310835',
#      'id': '960455228',
#      'featured': False,
#      'inventoryAvailable': '0',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 568,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/960455228',
#      'price': 6.99,
#      'basePrice': 6.99,
#      'pricePer': 4.66,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '0.500',
#      'slotXcoordinateNbr': '70.290',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'CT',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'DOZEN',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
#      'idOfDepartment': '1_11',
#      'warnings': [{}],
#      'requiresReturn': False,
#      'channelEligibility': {'pickUp': True,
#       'delivery': True,
#       'inStore': True,
#       'shipping': False},
#      'channelInventory': {'delivery': '0',
#       'pickup': '0',
#       'instore': '0',
#       'shipping': '0'},
#      'productReview': {'avgRating': '4.7',
#       'reviewCount': '225',
#       'isReviewWriteEligible': 'true',
#       'isReviewDisplayEligible': 'true',
#       'isForOnetimeReview': 'true',
#       'reviewTemplateType': 'default'}},
#     {'status': 'active',
#      'name': 'Lucerne 100% Liquid Egg Whites Cage Free - 32 OZ',
#      'pid': '970011837',
#      'upc': '0002113003584',
#      'id': '970011837',
#      'featured': False,
#      'inventoryAvailable': '1',
#      'pastPurchased': False,
#      'restrictedValue': '0',
#      'salesRank': 99999,
#      'agreementId': 0,
#      'featuredProductId': 0,
#      'imageUrl': 'https://images.albertsons-media.com/is/image/ABS/970011837',
#      'price': 6.79,
#      'basePrice': 6.79,
#      'pricePer': 0.21,
#      'displayType': '-1',
#      'aisleId': '1_11_3_1',
#      'aisleName': 'Eggs|1_11_3',
#      'departmentName': 'Dairy, Eggs & Cheese',
#      'shelfName': 'Eggs',
#      'shelfNameWithId': 'Eggs|1_11_3_1',
#      'aisleLocation': 'Dairy',
#      'shelfXcoordinateNbr': '0.000',
#      'shelfYcoordinateNbr': '51.000',
#      'slotXcoordinateNbr': '34.960',
#      'slotYcoordinateNbr': '0.000',
#      'fixtureXcoordinateNbr': '23329.860',
#      'fixtureYcoordinateNbr': '23950.320',
#      'aislePositionTxt': 'RIGHT',
#      'snapEligible': True,
#      'unitOfMeasure': 'OZ',
#      'sellByWeight': 'I',
#      'averageWeight': ['0.000'],
#      'unitQuantity': 'OUNCE',
#      'displayUnitQuantityText': 'ea',
#      'previousPurchaseQty': 0,
#      'maxPurchaseQty': 2,
#      'minWeight': '0.000',
#      'maxWeight': '0.000',
#      'prop65WarningIconRequired': False,
#      'isArProduct': True,
#      'isMtoProduct': False,
#      'isCustomizable': False,
#      'inStoreShoppingElig': False,
#      'preparationTime': '0',
#      'isMarketplaceItem': 'N',
#      'triggerQuantity': 0,
#      'idOfAisle': '1_11_3',
#      'idOfShelf': '1_11_3_1',
# ...
#      {'count': '124', 'name': 'Yogurt'},
#      {'count': '92', 'name': 'Milk Alternatives'},
#      {'count': '87', 'name': 'Egg Noodles'},
#      {'count': '70', 'name': 'Shredded Cheese'},
#      {'count': '68', 'name': 'Milk'},
#      {'count': '67', 'name': 'Coffee Creamer'},
#      {'count': '65', 'name': 'Sandwich Cheese'},
#      {'count': '54', 'name': 'Easter Candy'},
#      {'count': '52', 'name': 'Loaf & Block Cheese'},
#      {'count': '46', 'name': 'String & Snack Cheese'},
#      {'count': '45', 'name': 'Butter'},
#      {'count': '44', 'name': 'Breakfast Entrees'},
#      {'count': '44', 'name': 'Eggs'},
#      {'count': '38', 'name': 'Cream Cheese'},
#      {'count': '37', 'name': 'Gelatin & Pudding'},
#      {'count': '37', 'name': 'Probiotic Yogurt & Kefir'},
#      {'count': '34', 'name': 'Cottage Cheese'},
#      {'count': '34', 'name': 'Easter'},
#      {'count': '28', 'name': 'Breakfast Sandwiches'},
#      {'count': '26', 'name': 'Milk - Flavored'},
#      {'count': '23', 'name': 'Breakfast Burritos'},
#      {'count': '23', 'name': 'Margarine & Spreads'},
#      {'count': '23', 'name': 'Milk - Lactose Free'},
#      {'count': '21', 'name': 'Kids Yogurt'},
#      {'count': '20', 'name': 'Deli Side Dishes & Meals'},
#      {'count': '20', 'name': 'Sour Cream'},
#      {'count': '19', 'name': 'Grated & Topping Cheese'},
#      {'count': '16', 'name': 'Whipping Cream'},
#      {'count': '15', 'name': 'Asian Appetizers'},
#      {'count': '12', 'name': 'Half & Half'},
#      {'count': '11', 'name': 'Frozen Meals'},
#      {'count': '11', 'name': 'Kosher Foods'},
#      {'count': '9', 'name': 'Deli Salads'},
#      {'count': '8', 'name': 'Frozen Pasta & Sauce'},
#      {'count': '8', 'name': 'Herbs & Spices'},
#      {'count': '8', 'name': 'Mexican Appetizers'},
#      {'count': '8', 'name': 'Ricotta & Mozzarella'},
#      {'count': '7', 'name': 'Egg Substitute'},
#      {'count': '7', 'name': 'Linguine'},
#      {'count': '7', 'name': 'Pockets & Sandwiches'},
#      {'count': '5', 'name': 'Chocolate'},
#      {'count': '5', 'name': 'Frozen Juices'},
#      {'count': '5', 'name': 'Macaroni & Ditalini'},
#      {'count': '5', 'name': 'Soup Mix & Meals'},
#      {'count': '4', 'name': 'Buttermilk'},
#      {'count': '4', 'name': 'Fettuccine'},
#      {'count': '4', 'name': 'Food Coloring'},
#      {'count': '4', 'name': 'Frozen & Fresh Dog Food'},
#      {'count': '4', 'name': 'Frozen Meals Organic/Veg'},
#      {'count': '4', 'name': 'Gadgets & Utensils'},
#      {'count': '4', 'name': 'Matzo'},
#      {'count': '4', 'name': 'Pasta'},
#      {'count': '4', 'name': 'Specialty Vegetables'},
#      {'count': '3', 'name': 'Barbecue Sauce'},
#      {'count': '3', 'name': 'Breakfast Sausage'},
#      {'count': '3', 'name': 'Deli Sandwiches & Wraps'},
#      {'count': '3', 'name': 'Farfalle & Bowtie'},
#      {'count': '3', 'name': 'Frozen Meals Wellness'},
#      {'count': '3', 'name': 'Mayonnaise'},
#      {'count': '3', 'name': 'Seafood'},
#      {'count': '3', 'name': 'Snack Mixes'},
#      {'count': '3', 'name': 'Spread/Processed Cheese'},
#      {'count': '3', 'name': 'Sweeteners & Substitutes'},
#      {'count': '3', 'name': 'Tofu & Meat Alternatives'},
#      {'count': '3', 'name': 'Toys & Games'},
#      {'count': '3', 'name': 'Waffles'},
#      {'count': '2', 'name': 'Angel Hair & Spaghetti'},
#      {'count': '2', 'name': 'Baking Soda & Powder'},
#      {'count': '2', 'name': 'Breakfast Sausage'},
#      {'count': '2', 'name': 'Cocktails Ready To Drink'},
#      {'count': '2', 'name': 'Cookware'},
#      {'count': '2', 'name': 'Cordials & Liqueur'},
#      {'count': '2', 'name': 'Dog Food - Dry'},
#      {'count': '2', 'name': 'Dry Cat Food'},
#      {'count': '2', 'name': 'Dry Rice Noodles'},
#      {'count': '2', 'name': 'Dry Wheat Noodles'},
#      {'count': '2', 'name': 'Flavored Syrups'},
#      {'count': '2', 'name': 'Frozen Meals Multi-Serve'},
#      {'count': '2', 'name': 'Frozen Pies & Desserts'},
#      {'count': '2', 'name': 'Fruit & Vegetable Chips'},
#      {'count': '2', 'name': 'Halloween Candy'},
#      {'count': '2', 'name': 'Kosher Deli'},
#      {'count': '2', 'name': 'Lunch Packs'},
#      {'count': '2', 'name': 'Miscellaneous Household'},
#      {'count': '2', 'name': 'Oatmeal & Hot Cereal'},
#      {'count': '2', 'name': 'Pancakes & French Toast'},
#      {'count': '2', 'name': 'Pizza & Corn Dogs'},
#      {'count': '2', 'name': 'Sport Nutrition & Energy'},
#      {'count': '2', 'name': 'Storage Containers'},
#      {'count': '2', 'name': 'Valentine Candy'},
#      {'count': '1', 'name': 'Asian Specialty Foods'},
#      {'count': '1', 'name': 'Avocados'},
#      {'count': '1', 'name': 'Bacon'},
#      {'count': '1', 'name': 'Bananas'},
#      {'count': '1', 'name': 'Beef'},
#      {'count': '1', 'name': 'Bird Care'},
#      {'count': '1', 'name': 'Candy'},
#      {'count': '1', 'name': 'Cheesecake & Cream Cakes'},
#      {'count': '1', 'name': 'Cookies'},
#      {'count': '1', 'name': 'Cosmetics'},
#      {'count': '1', 'name': 'Croutons & Toppings'},
#      {'count': '1', 'name': 'Deli Condiments'},
#      {'count': '1', 'name': 'Dessert Decorations'},
#      {'count': '1', 'name': 'Dog Snacks'},
#      {'count': '1', 'name': 'Dog Supplies & Toys'},
#      {'count': '1', 'name': 'Dry Mixes'},
#      {'count': '1', 'name': 'Eggnog'},
#      {'count': '1', 'name': 'Frozen Bread & Bakery'},
#      {'count': '1', 'name': 'Frozen Pastry Dough'},
#      {'count': '1', 'name': 'Frozen Vegetables'},
#      {'count': '1', 'name': 'Gefilte Fish'},
#      {'count': '1', 'name': 'Gift Baskets'},
#      {'count': '1', 'name': 'Gravy & Glazes'},
#      {'count': '1', 'name': 'Ice Cream'},
#      {'count': '1', 'name': 'Instant Ramen & Noodles'},
#      {'count': '1', 'name': 'Lifestyle Nutrition'},
#      {'count': '1', 'name': 'Marinades'},
#      {'count': '1', 'name': 'Misc International Foods'},
#      {'count': '1', 'name': 'Orzo'},
#      {'count': '1', 'name': 'Other Animal Care'},
#      {'count': '1', 'name': 'Performance Shampoo Cond'},
#      {'count': '1', 'name': 'Pies, Tarts & Cobblers'},
#      {'count': '1', 'name': 'Popcorn'},
#      {'count': '1', 'name': 'Sewing Notions'},
#      {'count': '1', 'name': 'Skillet Dinners'},
#      {'count': '1', 'name': 'Skin Treatments'},
#      {'count': '1', 'name': 'Traditional Appetizers'},
#      {'count': '1', 'name': 'Wet Dog Food'}],
#     'shelfName_id': [{'count': '142', 'name': 'Greek Yogurt|1_11_8_1'},
#      {'count': '124', 'name': 'Yogurt|1_11_8_4'},
#      {'count': '92', 'name': 'Milk Alternatives|1_11_4_8'},
#      {'count': '87', 'name': 'Egg Noodles|1_6_4_3'},
#      {'count': '70', 'name': 'Shredded Cheese|1_11_11_7'},
#      {'count': '68', 'name': 'Milk|1_11_4_5'},
#      {'count': '67', 'name': 'Coffee Creamer|1_11_4_2'},
#      {'count': '65', 'name': 'Sandwich Cheese|1_11_11_6'},
#      {'count': '54', 'name': 'Easter Candy|1_24_15_2'},
#      {'count': '52', 'name': 'Loaf & Block Cheese|1_11_11_4'},
#      {'count': '46', 'name': 'String & Snack Cheese|1_11_11_9'},
#      {'count': '45', 'name': 'Butter|1_11_1_1'},
#      {'count': '44', 'name': 'Breakfast Entrees|1_7_3_2'},
#      {'count': '44', 'name': 'Eggs|1_11_3_1'},
#      {'count': '38', 'name': 'Cream Cheese|1_11_11_2'},
#      {'count': '37', 'name': 'Gelatin & Pudding|1_11_8_2'},
#      {'count': '37', 'name': 'Probiotic Yogurt & Kefir|1_11_8_3'},
#      {'count': '34', 'name': 'Cottage Cheese|1_11_11_1'},
#      {'count': '34', 'name': 'Easter|1_14_6_6'},
#      {'count': '28', 'name': 'Breakfast Sandwiches|1_7_3_3'},
#      {'count': '26', 'name': 'Milk - Flavored|1_11_4_6'},
#      {'count': '23', 'name': 'Breakfast Burritos|1_7_3_1'},
#      {'count': '23', 'name': 'Margarine & Spreads|1_11_1_5'},
#      {'count': '23', 'name': 'Milk - Lactose Free|1_11_4_7'},
#      {'count': '21', 'name': 'Kids Yogurt|1_11_8_5'},
#      {'count': '20', 'name': 'Deli Side Dishes & Meals|1_12_6_1'},
#      {'count': '20', 'name': 'Sour Cream|1_11_1_6'},
#      {'count': '19', 'name': 'Grated & Topping Cheese|1_11_11_3'},
#      {'count': '16', 'name': 'Whipping Cream|1_11_4_9'},
#      {'count': '15', 'name': 'Asian Appetizers|1_15_1_1'},
#      {'count': '12', 'name': 'Half & Half|1_11_4_4'},
#      {'count': '11', 'name': 'Frozen Meals|1_15_4_2'},
#      {'count': '11', 'name': 'Kosher Foods|1_13_3_1'},
#      {'count': '9', 'name': 'Deli Salads|1_12_5_1'},
#      {'count': '8', 'name': 'Frozen Pasta & Sauce|1_15_4_6'},
#      {'count': '8', 'name': 'Herbs & Spices|1_20_13_1'},
#      {'count': '8', 'name': 'Mexican Appetizers|1_15_1_2'},
#      {'count': '8', 'name': 'Ricotta & Mozzarella|1_11_11_5'},
#      {'count': '7', 'name': 'Egg Substitute|1_11_3_2'},
#      {'count': '7', 'name': 'Linguine|1_6_4_7'},
#      {'count': '7', 'name': 'Pockets & Sandwiches|1_15_1_4'},
#      {'count': '5', 'name': 'Chocolate|1_24_16_1'},
#      {'count': '5', 'name': 'Frozen Juices|1_15_6_1'},
#      {'count': '5', 'name': 'Macaroni & Ditalini|1_6_4_8'},
#      {'count': '5', 'name': 'Soup Mix & Meals|1_9_8_6'},
#      {'count': '4', 'name': 'Buttermilk|1_11_4_1'},
#      {'count': '4', 'name': 'Fettuccine|1_6_4_5'},
#      {'count': '4', 'name': 'Food Coloring|1_20_15_5'},
#      {'count': '4', 'name': 'Frozen & Fresh Dog Food|1_22_4_8'},
#      {'count': '4', 'name': 'Frozen Meals Organic/Veg|1_15_4_4'},
#      {'count': '4', 'name': 'Gadgets & Utensils|1_18_17_1'},
#      {'count': '4', 'name': 'Matzo|1_2_9_3'},
#      {'count': '4', 'name': 'Pasta|1_9_3_3'},
#      {'count': '4', 'name': 'Specialty Vegetables|1_23_2_19'},
#      {'count': '3', 'name': 'Barbecue Sauce|1_20_10_6'},
#      {'count': '3', 'name': 'Breakfast Sausage|1_19_8_2'},
#      {'count': '3', 'name': 'Deli Sandwiches & Wraps|1_12_11_1'},
#      {'count': '3', 'name': 'Farfalle & Bowtie|1_6_4_4'},
#      {'count': '3', 'name': 'Frozen Meals Wellness|1_15_4_5'},
#      {'count': '3', 'name': 'Mayonnaise|1_20_1_3'},
#      {'count': '3', 'name': 'Seafood|1_19_6_4'},
#      {'count': '3', 'name': 'Snack Mixes|1_24_1_9'},
#      {'count': '3', 'name': 'Spread/Processed Cheese|1_11_11_8'},
#      {'count': '3', 'name': 'Sweeteners & Substitutes|1_20_14_13'},
#      {'count': '3', 'name': 'Tofu & Meat Alternatives|1_23_4_5'},
#      {'count': '3', 'name': 'Toys & Games|1_18_7_43'},
#      {'count': '3', 'name': 'Waffles|1_7_3_9'},
#      {'count': '2', 'name': 'Angel Hair & Spaghetti|1_6_4_1'},
#      {'count': '2', 'name': 'Baking Soda & Powder|1_20_14_2'},
#      {'count': '2', 'name': 'Breakfast Sausage|1_7_3_4'},
#      {'count': '2', 'name': 'Cocktails Ready To Drink|1_29_2_2'},
#      {'count': '2', 'name': 'Cookware|1_18_17_4'},
#      {'count': '2', 'name': 'Cordials & Liqueur|1_29_2_4'},
#      {'count': '2', 'name': 'Dog Food - Dry|1_22_4_2'},
#      {'count': '2', 'name': 'Dry Cat Food|1_22_2_2'},
#      {'count': '2', 'name': 'Dry Rice Noodles|1_9_10_1'},
#      {'count': '2', 'name': 'Dry Wheat Noodles|1_9_10_2'},
#      {'count': '2', 'name': 'Flavored Syrups|1_5_3_6'},
#      {'count': '2', 'name': 'Frozen Meals Multi-Serve|1_15_4_3'},
#      {'count': '2', 'name': 'Frozen Pies & Desserts|1_15_3_3'},
#      {'count': '2', 'name': 'Fruit & Vegetable Chips|1_24_1_3'},
#      {'count': '2', 'name': 'Halloween Candy|1_24_15_3'},
#      {'count': '2', 'name': 'Kosher Deli|1_12_9_4'},
#      {'count': '2', 'name': 'Lunch Packs|1_19_7_5'},
#      {'count': '2', 'name': 'Miscellaneous Household|1_18_7_3'},
#      {'count': '2', 'name': 'Oatmeal & Hot Cereal|1_7_2_4'},
#      {'count': '2', 'name': 'Pancakes & French Toast|1_7_3_7'},
#      {'count': '2', 'name': 'Pizza & Corn Dogs|1_15_1_3'},
#      {'count': '2', 'name': 'Sport Nutrition & Energy|1_17_2_4'},
#      {'count': '2', 'name': 'Storage Containers|1_18_20_7'},
#      {'count': '2', 'name': 'Valentine Candy|1_24_15_4'},
#      {'count': '1', 'name': 'Asian Specialty Foods|1_13_1_51'},
#      {'count': '1', 'name': 'Avocados|1_23_1_2'},
#      {'count': '1', 'name': 'Bacon|1_19_8_1'},
#      {'count': '1', 'name': 'Bananas|1_23_1_3'},
#      {'count': '1', 'name': 'Beef|1_19_6_1'},
#      {'count': '1', 'name': 'Bird Care|1_22_5_1'},
#      {'count': '1', 'name': 'Candy|1_24_14_1'},
#      {'count': '1', 'name': 'Cheesecake & Cream Cakes|1_2_8_1'},
#      {'count': '1', 'name': 'Cookies|1_24_2_2'},
#      {'count': '1', 'name': 'Cosmetics|1_17_17_20'},
#      {'count': '1', 'name': 'Croutons & Toppings|1_20_7_1'},
#      {'count': '1', 'name': 'Deli Condiments|1_12_9_1'},
#      {'count': '1', 'name': 'Dessert Decorations|1_20_15_4'},
#      {'count': '1', 'name': 'Dog Snacks|1_22_4_1'},
#      {'count': '1', 'name': 'Dog Supplies & Toys|1_22_4_7'},
#      {'count': '1', 'name': 'Dry Mixes|1_20_10_9'},
#      {'count': '1', 'name': 'Eggnog|1_11_4_3'},
#      {'count': '1', 'name': 'Frozen Bread & Bakery|1_15_4_1'},
#      {'count': '1', 'name': 'Frozen Pastry Dough|1_15_3_2'},
#      {'count': '1', 'name': 'Frozen Vegetables|1_15_5_2'},
#      {'count': '1', 'name': 'Gefilte Fish|1_9_5_10'},
#      {'count': '1', 'name': 'Gift Baskets|1_14_2_8'},
#      {'count': '1', 'name': 'Gravy & Glazes|1_20_10_5'},
#      {'count': '1', 'name': 'Ice Cream|1_15_7_3'},
#      {'count': '1', 'name': 'Instant Ramen & Noodles|1_9_8_3'},
#      {'count': '1', 'name': 'Lifestyle Nutrition|1_17_2_11'},
#      {'count': '1', 'name': 'Marinades|1_20_10_3'},
#      {'count': '1', 'name': 'Misc International Foods|1_13_4_2'},
#      {'count': '1', 'name': 'Orzo|1_6_4_9'},
#      {'count': '1', 'name': 'Other Animal Care|1_22_5_3'},
#      {'count': '1', 'name': 'Performance Shampoo Cond|1_17_11_8'},
#      {'count': '1', 'name': 'Pies, Tarts & Cobblers|1_2_8_3'},
#      {'count': '1', 'name': 'Popcorn|1_24_9_3'},
#      {'count': '1', 'name': 'Sewing Notions|1_18_7_42'},
#      {'count': '1', 'name': 'Skillet Dinners|1_6_12_2'},
#      {'count': '1', 'name': 'Skin Treatments|1_17_19_4'},
#      {'count': '1', 'name': 'Traditional Appetizers|1_15_1_5'},
#      {'count': '1', 'name': 'Wet Dog Food|1_22_4_3'}],
#     'sellerName': [{'count': '152', 'name': 'FoodServiceDirect'},
#      {'count': '34', 'name': 'Universo Brands'},
#      {'count': '33', 'name': 'Elite Commerce'},
#      {'count': '23', 'name': 'Everyday Goods'},
#      {'count': '20', 'name': 'Cozy Farm'},
#      {'count': '20', 'name': 'Natural Bulk Goods'},
#      {'count': '8', 'name': 'ZiFiti Indian Grocer'},
#      {'count': '4', 'name': 'meDINEterranean'},
#      {'count': '3', 'name': 'Mantova Italian Food'},
#      {'count': '3', 'name': 'Valley Pet'},
#      {'count': '2', 'name': 'Trustables'},
#      {'count': '2', 'name': 'Wellnesstar'},
#      {'count': '2', 'name': 'iShopIndian Grocery'},
#      {'count': '1', 'name': 'Honest Medical'},
#      {'count': '1', 'name': 'Rani Indian Brand'}],
#     'nutritionContent': [{'count': '914',
#       'name': 'No High Fructose Corn Syrup'},
#      {'count': '524', 'name': 'Carb-conscious'},
#      {'count': '465', 'name': 'Sodium-conscious'},
#      {'count': '440', 'name': 'Keto-friendly'},
#      {'count': '381', 'name': 'No Added Sugars'},
#      {'count': '287', 'name': 'Protein pick'},
#      {'count': '176', 'name': 'Sugar-conscious'},
#      {'count': '137', 'name': 'Fat Free'},
#      {'count': '124', 'name': 'No Artificial Flavors'},
#      {'count': '105', 'name': 'Organic'},
#      {'count': '78', 'name': 'No Artificial Colors'},
#      {'count': '38', 'name': 'Paleo-friendly'},
#      {'count': '28', 'name': 'Plant-Based'},
#      {'count': '24', 'name': 'Fiber pick'},
#      {'count': '3', 'name': 'Whole Grain pick'},
#      {'count': '2', 'name': 'Heart Healthy'}],
#     'diet': [{'count': '1035', 'name': 'Pescatarian'},
#      {'count': '1035', 'name': 'Vegetarian'},
#      {'count': '671', 'name': 'Kosher'},
#      {'count': '139', 'name': 'Vegan'},
#      {'count': '6', 'name': 'Halal'}],
#     'dietaryRestriction': [{'count': '356', 'name': 'Gluten Free'},
#      {'count': '100', 'name': 'Lactose Free'},
#      {'count': '96', 'name': 'Milk Free'},
#      {'count': '58', 'name': 'Soy Free'},
#      {'count': '24', 'name': 'Peanut Free'},
#      {'count': '15', 'name': 'Egg Free'},
#      {'count': '5', 'name': 'Wheat Free'},
#      {'count': '4', 'name': 'Crustacean shellfish Free'},
#      {'count': '4', 'name': 'Fish Free'},
#      {'count': '4', 'name': 'Sesame Free'},
#      {'count': '4', 'name': 'Tree nut Free'}]}}},
#  'appCode': '[PS: 200]'}

# %%
results.raise_for_status

# %% [markdown]
# ### Scraping Tables with `pandas`
#
# For data in a `table` element, we can use __Pandas__ instead of writing a scraper.
#
# Wikipedia provides lots of useful information in tables. Let's get the Wikipedia list of [US cities by area][wiki].
#
# [wiki]: https://en.wikipedia.org/wiki/List_of_United_States_cities_by_area

# %%
import pandas as pd

# %%
tabs = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_area")

# %%
type(tabs)

# %%
len(tabs)

# %%
tabs[1]

# %%
tbl = tabs[1]
tbl.head()

# %% [markdown]
# To process this information, unusable items have to be removed. We are going to do that with `regex`. We will learn more about `regex` later on.

# %%
from re import sub 
def remove(string):
    '''
    Removes everything inside [], a whitespace before that and *'s.
    '''
    if isinstance(string, str):
        string = sub(r'\s*\[.*\]\**', '', string)
    return string

# %%
tbl['City'].iloc[4][0]

# %%
remove(tbl['City'].iloc[4][0])

# %%
remove(1706.8)

# %%
tbl.columns = [remove(i) for i in tbl.columns] # remove from table columns

# %%
tbl = tbl.applymap(remove) #remove from all rows

# %%
tbl.head()

# %%
tbl.dtypes

# %% [markdown]
# ### HTML
#
# Web pages are written in _hypertext markup language_ (HTML). HTML files (`.htm` or `.html`) are plain text, just like JSON, Python scripts, and R scripts.
#
# In HTML, we use _tags_ to create _elements_ of a web page. Elements add formatting and structure to the page.
#
# * Tags usually come in pairs: an opening tag and a closing tag.
# * Tags are written `<NAME>` for opening tags, `</NAME>` for closing tags, and `<NAME />` for singleton tags.
# * Opening and singleton tags can have _attributes_ that contain additional information. Attributes are written `ATTRIBUTE=VALUE` after the tag name.
#
# See [here](https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/HTML_basics) for a more detailed explanation, and [here](https://developer.mozilla.org/en-US/docs/Web/HTML/Element) for a list of valid HTML elements.
#
# #### Example
#
# [wiki]: https://en.wikipedia.org/wiki/List_of_United_States_cities_by_area
#
# From now on, we will use an artificial an example:
#
# ```html
# <p>This page is famous and this <b>word</b> is emphasized.</p>
# ```
#
# ```html
# <p>This <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ">page</a> is famous and this <strong>word</strong> is emphasized.</p>
# ```
#
# ```html
# <li>1. Something</li>
# ```

# %% [markdown]
# <p>This page is famous and this <b>word</b> is emphasized.</p>
# <p>This <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ">page</a> is famous and this <strong>word</strong> is emphasized.</p>
# <li>1. Something</li>

# %% [markdown]
# The `p` tag marks a paragraph, the `a` tag marks a link (an _anchor_), the `strong` tag marks emphasized text,
# and `li` tag marks a list.
#
# Here's a string that contains HTML for a simple, complete website:

# %%
page = """
<html>
<head>
    <title>This is the Title!</title>
</head>

<body>
    <p>This is a paragraph!</p>
    <p id="best-paragraph">This is another paragraph! &#127790;</p>
    <p>Visit <a href="https://pudding.cool">The Pudding</a>.</p>
    <span>This is a span, it comes with an taco &#127790;</span>
</body>
<a href="https://pudding.cool">The Pudding</a>
sadfasdf
</html>
"""

# %%
page

# %% [markdown]
# <html>
# <head>
#     <title>This is the Title!</title>
# </head>
#
# <body>
#     <p>This is a paragraph!</p>
#     <p id="best-paragraph">This is another paragraph! &#127790;</p>
#     <p>Visit <a href="https://pudding.cool">The Pudding</a>.</p>
#     <span>This is a span, it comes with an taco &#127790;</span>
# </body>
#
# <body>
#     <p>This is a new paragraph!</p>
# </body>
#
# </html>

# %% [markdown]
# The `<span>` tag is an inline container used to mark up a part of a text, or a part of a document.
#
# For example, you can write the code
# ```
# <p>My hat is <span style="color:blue">blue</span>.</p>
# ```
#
# <p>My hat is <span style="color:blue">blue</span>.</p>

# %% [markdown]
# ### XML
#
# _Extensible markup language_ (XML) also uses tags to create elements. We say XML is _extensible_ because you can create your own XML elements (unlike HTML). People typically use XML to describe structure and meaning of data, rather than for formatting.
#
# We'll use the same process to extract data from both HTML and XML.

# %% [markdown]
# ### Parser
#
# A _parser_ converts formatted data into familiar data structures. We've used __requests__' built-in JSON parser, but the package doesn't have a built-in HTML/XML parser. Fortunately, there are many other Python packages for parsing HTML/XML and web scraping.
#
# HTML/XML Parsers:
# * [lxml](https://lxml.de/)
# * [html5lib](https://github.com/html5lib/html5lib-python)
# * [beautifulsoup](https://www.crummy.com/software/BeautifulSoup/)
# * [requests-html](https://docs.python-requests.org/projects/requests-html/en/latest/)
#
# Scraper Frameworks (_convenient after learning the basics with parsers_):
# * [scrapy](https://scrapy.org/)
# * [newspaper3k](https://github.com/codelucas/newspaper)
#
# Even more [here](https://github.com/lorien/awesome-web-scraping/blob/master/python.md#web-scraping-frameworks).
#
# We'll use __lxml__ here (check the [doc](https://lxml.de/apidoc/index.html)), but you're welcome to use other packages on assignments and the project.

# %%
import lxml.html as lx

html = lx.fromstring(page)
html

# %% [markdown]
# <html>
# <head>
#     <title>This is the Title!</title>
# </head>
#
# <body>
#     <p>This is a paragraph!</p>
#     <p id="best-paragraph">This is another paragraph! &#127790;</p>
#     <p>Visit <a href="https://pudding.cool">The Pudding</a>.</p>
#     <span>This is a span, it comes with an taco &#127790;</span>
# </body>
# </html>

# %% [markdown]
# #### Finding Elements
#
# Elements are nested, so an HTML document is like a tree:
# ```
# html
# ├── head
# │   └── title
# └── body
#     ├── p
#     ├── p
#     ├── p
#     │   └── a
#     └── span
# ```
# This is similar to the file system on your computer. The key difference is that elements at the same level can have the same tag name.

# %% [markdown]
# #### XPath
#
# The _XML Path Language_ (XPath) lets us write paths to elements. XPath paths look a lot like file paths. XPath is not Python-specific!
#
# The `.xpath()` method gets all elements at an XPath path:

# %%
html.xpath("/html/head/title")

# %%
html.xpath("/html/body/p/a")

# %% [markdown]
# Since there may be more than one element, the method always returns a list.
#
# Absolute paths are not robust for scraping. An update to a web page that adds a single tag can break a scraper that uses absolute paths. In XPath, `//` means "anywhere below". We'll use `//` often because it's more robust:

# %%
html.xpath("//a")

# %% [markdown]
# What if we just elements want that satisfy a certain condition? In XPath, `[ ]` filters out elements that don't match a condition. For example:

# %%
html.xpath("//p[@id = 'best-paragraph']")

# %% [markdown]
# [XPath Diner](http://www.topswagcode.com/xpath/) is an interactive tutorial that teaches most of the XPath syntax. It takes about 20-60 minutes. Work through it to become an XPath ninja!
#
# You can copy the absolute path of a tag from the developer tools.

# %%
'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr[7]/td[3]'

# %% [markdown]
# #### CSS Selectors
#
# _Cascading Style Sheets_ (CSS) is another language for formatting elements in an HTML document. CSS provides another way to select elements, called _CSS selectors_.
#
# CSS selectors are more concise but less flexible than XPath paths. The `.cssselect()` method gets all elements at a CSS selector:

# %%
html.cssselect("a")

# %% [markdown]
# Check out the [CSS Diner](https://flukeout.github.io/)!

# %% [markdown]
# ### Extracting Text and Attributes
#
# There are two ways to get text from an element:
#
# * `.text` gives text inside the element, but not its children
# * `.text_content()` gives text inside the element and its children, with all tags removed

# %%
page

# %%
html.text_content()

# %%
a = html.xpath("//a")[0]

# %%
a.text_content()

# %%
a.text

# %%
html.text_content()

# %%
html.text

# %% [markdown]
# We can get values from attributes on an element with `.attrib`, which is a dictionary:

# %%
a.attrib["href"]

# %%
[x.attrib["href"] for x in html.xpath("//a")]

# %% [markdown]
# ### Writing Scrapers
#
# Lets scrape the wiki table ourselves. Attention: We are using request, so pay attention to the file that is being returned. Check on devtools the html element for `<thead>` and see what is returned in the network.

# %%
import requests

result = requests.get(url = 'https://en.wikipedia.org/wiki/List_of_United_States_cities_by_area')
html = lx.fromstring(result.text)

# %%
tables = html.xpath('//table')
table = tables[1]

# %%
table.text_content()

# %%
html.xpath('//table[2]/thead')

# %%
html.xpath('//table[2]/tbody')

# %%
def retrieve_rows(html): 
    rows = html.xpath('//table[2]/tbody/tr')
    cells = []
    for row in rows: 
        # ./td|th means we start at the node (not searching the whole doc again), and choose td OR th children
        cells.append([cell.text_content() for cell in row.xpath('./td|th')]) # no text, as some cells are in <b>
    return cells

# %%
retrieve_rows(html)

# %%
df = pd.DataFrame(retrieve_rows(html))
df.head()

# %%
df.columns = df.iloc[0]
df = df.drop(index = range(2))
df.head()

# %%
df.dtypes

# %%
from re import sub 
def remove(string):
    '''
    Removes everything inside [], a whitespace before that and *'s.
    '''
    if isinstance(string, str):
        string = sub(r'\s*\[.*\]\**|\n|,', '', string)
    return string

# %%
df.columns = [remove(i) for i in df.columns] # remove from table columns
df = df.applymap(remove) #remove from all rows
df.head()

# %%
df.dtypes

# %%
for col in df.columns[3:]: #only those cols with vals
    df[col] = df[col].astype(float)

# %%
df.head()

# %%
df.dtypes

# %% [markdown]
# ### Summary
#
# - HTML pages are set up like a filesystem
# - use `lxml` to parse them in Python
# - navigate though HTML via xpath or css
